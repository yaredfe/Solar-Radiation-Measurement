# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\User\\Downloads\\film\\Solar-Radiation-Measurement\\notebooks\\new_data_sets\\cleaned_data_for_sierraleone_bumbuna.CSV")

# %%
data.head()
# Out:
#    Unnamed: 0         Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  \
# 0           0  2021-10-30 00:01  0.7  0.1  0.8   0.0   0.0  21.9  99.1  0.0
# 1           1  2021-10-30 00:02  0.7  0.1  0.8   0.0   0.0  21.9  99.2  0.0
# 2           2  2021-10-30 00:03  0.7  0.1  0.8   0.0   0.0  21.9  99.2  0.0
# 3           3  2021-10-30 00:04  0.7  0.0  0.8   0.0   0.0  21.9  99.3  0.0
# 4           4  2021-10-30 00:05  0.7  0.1  0.8   0.0   0.0  21.9  99.3  0.0
#
#    ...  WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0  ...      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 1  ...      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 2  ...      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 3  ...      0.0  0.0      0.0  1002         0            0.1   22.3   22.6
# 4  ...      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
#
#    Comments  WS_z_score
# 0       0.0   -0.590699
# ...

# %%
data.drop(columns="Unnamed: 0",axis=1)
# Out:
#                Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb     RH   WS  WSgust  \
# 0       2021-10-30 00:01  0.7  0.1  0.8   0.0   0.0  21.9   99.1  0.0     0.0
# 1       2021-10-30 00:02  0.7  0.1  0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 2       2021-10-30 00:03  0.7  0.1  0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 3       2021-10-30 00:04  0.7  0.0  0.8   0.0   0.0  21.9   99.3  0.0     0.0
# 4       2021-10-30 00:05  0.7  0.1  0.8   0.0   0.0  21.9   99.3  0.0     0.0
# ...                  ...  ...  ...  ...   ...   ...   ...    ...  ...     ...
# 246794  2022-10-29 23:56  1.6  0.1  2.9   0.0   0.0  24.0  100.0  0.0     0.0
# 246795  2022-10-29 23:57  1.7  0.1  3.0   0.0   0.0  24.0  100.0  0.0     0.0
# 246796  2022-10-29 23:58  1.7  0.1  3.1   0.0   0.0  24.0  100.0  0.0     0.0
# 246797  2022-10-29 23:59  1.7  0.2  3.3   0.0   0.0  23.9  100.0  0.0     0.0
# 246798  2022-10-30 00:00  1.7  0.1  3.4   0.0   0.0  23.9  100.0  0.0     0.0
#
# ...

# %%
data.set_index('Timestamp',inplace=True)
# this code well make the time stamp be the index for the data set

# %%
data.head()
# Out:
#                   Unnamed: 0  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  \
# Timestamp
# 2021-10-30 00:01           0  0.7  0.1  0.8   0.0   0.0  21.9  99.1  0.0
# 2021-10-30 00:02           1  0.7  0.1  0.8   0.0   0.0  21.9  99.2  0.0
# 2021-10-30 00:03           2  0.7  0.1  0.8   0.0   0.0  21.9  99.2  0.0
# 2021-10-30 00:04           3  0.7  0.0  0.8   0.0   0.0  21.9  99.3  0.0
# 2021-10-30 00:05           4  0.7  0.1  0.8   0.0   0.0  21.9  99.3  0.0
#
#                   WSgust  WSstdev   WD  WDstdev    BP  Cleaning  \
# Timestamp
# 2021-10-30 00:01     0.0      0.0  0.0      0.0  1002         0
# 2021-10-30 00:02     0.0      0.0  0.0      0.0  1002         0
# 2021-10-30 00:03     0.0      0.0  0.0      0.0  1002         0
# 2021-10-30 00:04     0.0      0.0  0.0      0.0  1002         0
# 2021-10-30 00:05     0.0      0.0  0.0      0.0  1002         0
#
#                   Precipitation  TModA  TModB  Comments  WS_z_score
# Timestamp
# ...

# %%
data.drop(columns="Unnamed: 0",axis=1)
# Out:
#                   GHI  DNI  DHI  ModA  ModB  Tamb     RH   WS  WSgust  \
# Timestamp
# 2021-10-30 00:01  0.7  0.1  0.8   0.0   0.0  21.9   99.1  0.0     0.0
# 2021-10-30 00:02  0.7  0.1  0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 2021-10-30 00:03  0.7  0.1  0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 2021-10-30 00:04  0.7  0.0  0.8   0.0   0.0  21.9   99.3  0.0     0.0
# 2021-10-30 00:05  0.7  0.1  0.8   0.0   0.0  21.9   99.3  0.0     0.0
# ...               ...  ...  ...   ...   ...   ...    ...  ...     ...
# 2022-10-29 23:56  1.6  0.1  2.9   0.0   0.0  24.0  100.0  0.0     0.0
# 2022-10-29 23:57  1.7  0.1  3.0   0.0   0.0  24.0  100.0  0.0     0.0
# 2022-10-29 23:58  1.7  0.1  3.1   0.0   0.0  24.0  100.0  0.0     0.0
# 2022-10-29 23:59  1.7  0.2  3.3   0.0   0.0  23.9  100.0  0.0     0.0
# 2022-10-30 00:00  1.7  0.1  3.4   0.0   0.0  23.9  100.0  0.0     0.0
#
#                   WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  \
# Timestamp
# ...

# %%
plt.figure(figsize=(14, 6))

# Plot each feature
plt.plot(data['GHI'].iloc[:1000], label='GHI')  # Plot GHI data
plt.plot(data['DNI'].iloc[:1000], label='DNI')  # Plot DNI data
plt.plot(data['DHI'].iloc[:1000], label='DHI')  # Plot DHI data
plt.plot(data['Tamb'].iloc[:1000], label='Tamb')  # Plot Tamb data

# Add titles and labels
plt.title('Time Series of Solar Irradiance and Temperature')
plt.xlabel('Time')
plt.ylabel('Values')

# Add legend
plt.legend()

# Set x-ticks at every 10th data point
tick_positions = np.arange(0, len(data['GHI'].iloc[:1000]), 30)  # Adjust the interval as needed
plt.xticks(tick_positions, rotation=50)  # Rotate x-axis labels by 50 degrees for better readability

# Display the plot
plt.show()

# Save the plot to a file
plt.savefig("time_series3.png")

# %%
sampled_df = data.sample(frac=0.1, random_state=1)

# %%
corr = sampled_df[['GHI', 'DNI', 'DHI', 'TModA', 'TModB']].corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of Solar Radiation and Temperature Measures')
plt.show()
plt.savefig("3.1heatmap.jpg")

# %%
sns.pairplot(sampled_df[['GHI', 'DNI', 'DHI', 'TModA', 'TModB']])
plt.suptitle('Pair Plot of Solar Radiation and Temperature Measures', y=1.02)
plt.show()
plt.savefig("3.1pair plot.jpg")
# Out:
# C:\Users\User\Downloads\film\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(sampled_df[['GHI', 'DNI', 'DHI', 'WS', 'WSgust', 'WD']])
plt.suptitle('Scatter Matrix of Wind Conditions and Solar Irradiance', y=1.02)
plt.show()
plt.savefig("3.1scatter matric.jpg")
# Out:
# C:\Users\User\Downloads\film\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
